# %% [markdown]
# # CampX — DS Experiments
# Exploratory analysis and model experiments for the Campaign Optimization Engine.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Load Data

# %%
# Load synthetic data from outputs
# df = pd.read_csv('outputs/synthetic_data/interactions.csv')
# df.head()

# %% [markdown]
# ## 2. EDA

# %%
# df.describe()

# %% [markdown]
# ## 3. Baseline Model Experiments

# %%
# See baselines.py for implemented baselines
# See model.py for LinUCB implementation
